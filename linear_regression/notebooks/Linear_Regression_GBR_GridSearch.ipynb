# %% [markdown]
# # Notebook was made using Google Colab
#
# [Link to Notebook](https://colab.research.google.com/drive/1z8X7JRmKwWuaiC9fLI9nSUkFLDItYNhg?usp=sharing)

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV

from feature_select import Train

# %%
train = Train(pd.read_csv('train_cleaned.csv'))

# %%
features = list(train.cleaned.columns)
features.remove('SalePrice')
target = 'SalePrice'

X_train, y_train, X_val, y_val, X_test, y_test = train.train_val_test_split(
    X=train.cleaned[features],
    y=train.cleaned[target],
    random_state=42)

print(X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape)
# Out:
# (751, 25) (751,) (251, 25) (251,) (251, 25) (251,)

# %%
from sklearn.metrics import make_scorer, mean_squared_log_error

def rmsle(predicted, actual, size):
    return np.sqrt(np.nansum(np.square(np.log(predicted + 1) - np.log(actual + 1)))/float(size))

scorer = make_scorer(rmsle, greater_is_better=False, size=10)

# %%
def make_model(param_grid, scoring=scorer, cv=5):
  gbr = GradientBoostingRegressor(random_state=42)
  grid_search = GridSearchCV(gbr, scoring=scorer, cv=cv, param_grid=param_grid,
                             n_jobs=-1, verbose=10)
  return grid_search

grid = {
    'learning_rate': [1, 0.1, 0.01, 0.001, 0.0001],
    'n_estimators': [100, 200, 300, 400, 500],
    'max_depth': [x for x in range(1,6)],
    'min_samples_leaf': [x for x in range(1,6)],
    'max_features': [0.25, 0.75, 'auto', 'sqrt', 'log2']
}

model = make_model(grid)

# %%
model
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0,
#                                                  criterion='friedman_mse',
#                                                  init=None, learning_rate=0.1,
#                                                  loss='ls', max_depth=3,
#                                                  max_features=None,
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  n_estimators=100,
#                                                  n_iter_n...
#              iid='deprecated', n_jobs=-1,
#              param_grid={'learning_rate': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'max_depth': [1, 2, 3, 4, 5],
#                          'max_features': [0.25, 0.75, 'auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 3, 4, 5],
#                          'n_estimators': [100, 200, 300, 400, 500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(rmsle, greater_is_better=False, size=10),
#              verbose=10)

# %%
model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 3125 candidates, totalling 15625 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=-1)]: Done 177 tasks      | elapsed:   18.2s
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:
# [Parallel(n_jobs=-1)]: Done 9937 tasks      | elapsed: 27.6min
# [Parallel(n_jobs=-1)]: Done 10078 tasks      | elapsed: 27.8min
# [Parallel(n_jobs=-1)]: Done 10221 tasks      | elapsed: 28.2min
# [Parallel(n_jobs=-1)]: Done 10364 tasks      | elapsed: 28.6min
# [Parallel(n_jobs=-1)]: Done 10509 tasks      | elapsed: 28.9min
# [Parallel(n_jobs=-1)]: Done 10654 tasks      | elapsed: 29.1min
# [Parallel(n_jobs=-1)]: Done 10801 tasks      | elapsed: 29.5min
# [Parallel(n_jobs=-1)]: Done 10948 tasks      | elapsed: 30.1min
# [Parallel(n_jobs=-1)]: Done 11097 tasks      | elapsed: 30.5min
# [Parallel(n_jobs=-1)]: Done 11246 tasks      | elapsed: 30.8min
# [Parallel(n_jobs=-1)]: Done 11397 tasks      | elapsed: 31.2min
# [Parallel(n_jobs=-1)]: Done 11548 tasks      | elapsed: 31.9min
# [Parallel(n_jobs=-1)]: Done 11701 tasks      | elapsed: 32.5min
# [Parallel(n_jobs=-1)]: Done 11854 tasks      | elapsed: 32.8min
# [Parallel(n_jobs=-1)]: Done 12009 tasks      | elapsed: 33.2min
# [Parallel(n_jobs=-1)]: Done 12164 tasks      | elapsed: 34.1min
# [Parallel(n_jobs=-1)]: Done 12321 tasks      | elapsed: 34.9min
# [Parallel(n_jobs=-1)]: Done 12478 tasks      | elapsed: 35.3min
# [Parallel(n_jobs=-1)]: Done 12637 tasks      | elapsed: 35.5min
# [Parallel(n_jobs=-1)]: Done 12796 tasks      | elapsed: 35.8min
# [Parallel(n_jobs=-1)]: Done 12957 tasks      | elapsed: 36.1min
# [Parallel(n_jobs=-1)]: Done 13118 tasks      | elapsed: 36.3min
# [Parallel(n_jobs=-1)]: Done 13281 tasks      | elapsed: 36.6min
# [Parallel(n_jobs=-1)]: Done 13444 tasks      | elapsed: 37.1min
# [Parallel(n_jobs=-1)]: Done 13609 tasks      | elapsed: 37.4min
# [Parallel(n_jobs=-1)]: Done 13774 tasks      | elapsed: 37.7min
# [Parallel(n_jobs=-1)]: Done 13941 tasks      | elapsed: 38.1min
# [Parallel(n_jobs=-1)]: Done 14108 tasks      | elapsed: 38.8min
# [Parallel(n_jobs=-1)]: Done 14277 tasks      | elapsed: 39.2min
# [Parallel(n_jobs=-1)]: Done 14446 tasks      | elapsed: 39.5min
# [Parallel(n_jobs=-1)]: Done 14617 tasks      | elapsed: 40.2min
# [Parallel(n_jobs=-1)]: Done 14788 tasks      | elapsed: 41.0min
# [Parallel(n_jobs=-1)]: Done 14961 tasks      | elapsed: 41.4min
# [Parallel(n_jobs=-1)]: Done 15134 tasks      | elapsed: 41.9min
# [Parallel(n_jobs=-1)]: Done 15309 tasks      | elapsed: 42.9min
# [Parallel(n_jobs=-1)]: Done 15484 tasks      | elapsed: 43.7min
# [Parallel(n_jobs=-1)]: Done 15625 out of 15625 | elapsed: 44.0min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0,
#                                                  criterion='friedman_mse',
#                                                  init=None, learning_rate=0.1,
#                                                  loss='ls', max_depth=3,
#                                                  max_features=None,
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  n_estimators=100,
#                                                  n_iter_n...
#              iid='deprecated', n_jobs=-1,
#              param_grid={'learning_rate': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'max_depth': [1, 2, 3, 4, 5],
#                          'max_features': [0.25, 0.75, 'auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 3, 4, 5],
#                          'n_estimators': [100, 200, 300, 400, 500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(rmsle, greater_is_better=False, size=10),
#              verbose=10)

# %%
y_pred_val = model.predict(X_val)
y_pred_test = model.predict(X_test)

print('Val Score: ', model.score(X_val, y_val))
print('Test Score: ', model.score(X_test, y_test))

rmsle_val = np.sqrt(mean_squared_log_error(y_pred_val, y_val))
rmsle_test = np.sqrt(mean_squared_log_error(y_pred_test, y_test))

print(f'Val RMSLE: {rmsle_val}')
print(f'Test RMSLE: {rmsle_test}')
# Out:
# Val Score:  -0.7856488014989083
# Test Score:  -0.7653944040374953
# Val RMSLE: 0.15681644042610832
# Test RMSLE: 0.15277363846826836

# %%
model.best_params_
# Out:
# {'learning_rate': 0.1,
#  'max_depth': 5,
#  'max_features': 0.25,
#  'min_samples_leaf': 5,
#  'n_estimators': 100}

# %%
model.best_score_
# Out:
# -0.5600546836101257

# %%
test.cleaned.head()
# Out:
#      Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0  1461          20       RH  ...    2010        WD        Normal
# 1  1462          20       RL  ...    2010        WD        Normal
# 2  1463          60       RL  ...    2010        WD        Normal
# 3  1464          60       RL  ...    2010        WD        Normal
# 4  1465         120       RL  ...    2010        WD        Normal
#
# [5 rows x 80 columns]

# %%
test = Train(pd.read_csv('test.csv'))
cleaned_df = test.clean_df()

# %%
cleaned_df.head()
# Out:
#      Id  LotArea  TotalBsmtSF  1stFlrSF  ...  HasDeck  HasPool  MonthSold  YearSold
# 0  1461    11622        882.0       896  ...        1        0          5         4
# 1  1462    14267       1329.0      1329  ...        1        0          5         4
# 2  1463    13830        928.0       928  ...        1        0          2         4
# 3  1464     9978        926.0       926  ...        1        0          5         4
# 4  1465     5005       1280.0      1280  ...        0        0          0         4
#
# [5 rows x 26 columns]

# %%
IDs = cleaned_df['Id']
feat = cleaned_df[cleaned_df.columns[1:]]

# %%
y_pred = model.predict(feat)
submission_gs_gbr = pd.DataFrame({'Id': IDs, 'SalePrice': y_pred})
submission_gs_gbr.head()
# Out:
#      Id      SalePrice
# 0  1461  122661.099857
# 1  1462  157634.141995
# 2  1463  184338.662334
# 3  1464  181461.026060
# 4  1465  184500.783411

# %%
# Submission received 0.18596 which is ~0.005 better than the previous

# submission_gs_gbr.to_csv('grid_search_gbr0.csv', index=False)
